# %%
import pandas as pd

# %%
pd.date_range("2023-01-01", "2023-01-31", freq="W-MON")
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-09', '2023-01-16', '2023-01-23',
#                '2023-01-30'],
#               dtype='datetime64[ns]', freq='W-MON')

# %%
# generate ticks every 2day 3hours 20minutes and 40sek
pd.date_range("2023-01-01", "2023-01-31", freq="2D3H20MIN40S")
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-03 03:20:40',
#                '2023-01-05 06:41:20', '2023-01-07 10:02:00',
#                '2023-01-09 13:22:40', '2023-01-11 16:43:20',
#                '2023-01-13 20:04:00', '2023-01-15 23:24:40',
#                '2023-01-18 02:45:20', '2023-01-20 06:06:00',
#                '2023-01-22 09:26:40', '2023-01-24 12:47:20',
#                '2023-01-26 16:08:00', '2023-01-28 19:28:40',
#                '2023-01-30 22:49:20'],
#               dtype='datetime64[ns]', freq='184840S')

# %%
df = pd.read_csv("https://stooq.com/q/d/l/?s=cdr&d1=20200101&d2=20220114&i=d")
df
# Out:
#            Date     Open     High      Low    Close         Volume
# 0    2020-01-02  271.302  275.924  270.342  275.924  174088.134909
# 1    2020-01-03  276.112  278.814  270.441  275.152  253592.737636
# 2    2020-01-07  276.211  277.468  272.173  273.034  221256.642750
# 3    2020-01-08  272.747  273.034  266.788  270.441  233313.724433
# 4    2020-01-09  273.232  277.656  272.272  277.656  202579.986808
# ..          ...      ...      ...      ...      ...            ...
# 507  2022-01-10  196.573  197.622  186.180  186.180  407499.859755
# 508  2022-01-11  187.566  191.129  186.279  186.635  347083.110577
# 509  2022-01-12  187.368  194.652  184.101  193.999  529395.197632
# 510  2022-01-13  191.030  195.741  190.040  191.050  297485.809007
# 511  2022-01-14  190.990  193.346  187.763  189.050  259348.493824
#
# [512 rows x 6 columns]

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
df.Date = pd.to_datetime(df.Date, format="%Y-%m-%d")
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.set_index("Date", inplace=True)
df.head()
# Out:
#                Open     High      Low    Close         Volume
# Date
# 2020-01-02  271.302  275.924  270.342  275.924  174088.134909
# 2020-01-03  276.112  278.814  270.441  275.152  253592.737636
# 2020-01-07  276.211  277.468  272.173  273.034  221256.642750
# 2020-01-08  272.747  273.034  266.788  270.441  233313.724433
# 2020-01-09  273.232  277.656  272.272  277.656  202579.986808

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14',
#                '2020-01-15', '2020-01-16',
#                ...
#                '2021-12-30', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14'],
#               dtype='datetime64[ns]', name='Date', length=512, freq=None)

# %%
df.Close.plot(color='red', grid=True, figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.loc["2021-12"].Close.plot(color='red', grid=True, figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot(color='red', grid=True, figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# calculate highest close quote in every year
df.Close.resample("YS").max().plot(kind='bar', color='red', grid=True, figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# calculate lowest close quote in every quarter
df.Close.resample("Q").min().plot(kind='bar', color='red', grid=True, figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-13', '2020-01-14',
#                '2020-01-15', '2020-01-16',
#                ...
#                '2021-12-30', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14'],
#               dtype='datetime64[ns]', name='Date', length=512, freq=None)
