# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("http://51.91.120.89/extras/gapminderDataFiveYear.csv").query(" year==2007 ")
df
# Out:
#                  country  year         pop continent  lifeExp     gdpPercap
# 11           Afghanistan  2007  31889923.0      Asia   43.828    974.580338
# 23               Albania  2007   3600523.0    Europe   76.423   5937.029526
# 35               Algeria  2007  33333216.0    Africa   72.301   6223.367465
# 47                Angola  2007  12420476.0    Africa   42.731   4797.231267
# 59             Argentina  2007  40301927.0  Americas   75.320  12779.379640
# ...                  ...   ...         ...       ...      ...           ...
# 1655             Vietnam  2007  85262356.0      Asia   74.249   2441.576404
# 1667  West Bank and Gaza  2007   4018332.0      Asia   73.422   3025.349798
# 1679         Yemen, Rep.  2007  22211743.0      Asia   62.698   2280.769906
# 1691              Zambia  2007  11746035.0    Africa   42.384   1271.211593
# 1703            Zimbabwe  2007  12311143.0    Africa   43.487    469.709298
#
# [142 rows x 6 columns]

# %%
sns.lmplot(data=df, x="lifeExp", y="gdpPercap", fit_reg=False, aspect=2.5, hue="continent")
plt.grid()
plt.show()

# %%
sns.lmplot(data=df, x="lifeExp", y="gdpPercap", fit_reg=False, aspect=0.7, col="continent")
plt.show()

# %%
sns.jointplot(data=df, x="lifeExp", y="gdpPercap", kind="scatter")

# %%
sns.jointplot(data=df, x="lifeExp", y="gdpPercap", kind="hex")

# %%
sns.jointplot(data=df, x="lifeExp", y="gdpPercap", kind="kde")

# %%
# classic line chart
df = pd.read_csv("https://covid19.who.int/WHO-COVID-19-global-data.csv")
df.sample(n=10)
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 82719     2021-10-03           FR                    France       EURO
# 135883    2020-08-13           LY                     Libya       EMRO
# 42238     2020-03-01           CA                    Canada       AMRO
# 123646    2021-06-12           KZ                Kazakhstan       EURO
# 220241    2020-08-11           SG                 Singapore       WPRO
# 257725    2020-03-28           US  United States of America       AMRO
# 215883    2021-03-01           SN                   Senegal       AFRO
# 187464    2021-05-21           PE                      Peru       AMRO
# 122871    2022-06-12           JO                    Jordan       EMRO
# 212848    2022-03-21           SM                San Marino       EURO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 82719        4948           6808026          30             114498
# ...

# %%
df.Date_reported = pd.to_datetime(df.Date_reported, format="%Y-%m-%d")

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.query("Country_code=='PL' and Date_reported>='2023-01-01'") , 
             x="Date_reported", y="New_cases", color="red" )

sns.lineplot(data=df.query("Country_code=='DE' and Date_reported>='2023-01-01'") , 
             x="Date_reported", y="New_cases", color="green" )

sns.lineplot(data=df.query("Country_code=='FR' and Date_reported>='2023-01-01'") , 
             x="Date_reported", y="New_cases", color="blue" )

plt.grid()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.query("Country_code in ['PL','DE','FR'] and Date_reported>='2023-01-01'") , 
             x="Date_reported", y="New_cases", hue="Country_code" )


plt.grid()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(data=df, x="class")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df, y="class")
# Out:
# <AxesSubplot:xlabel='count', ylabel='class'>

# %%
sns.countplot(data=df, x="class", hue="sex")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df = sns.load_dataset("car_crashes").sort_values("total", ascending=False)
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# ...

# %%
plt.figure(figsize=(10,15))
sns.barplot(data=df, x="total", y="abbrev", color="#0000FF", label='Total')
sns.barplot(data=df, x="alcohol", y="abbrev", color="#FF0000", label='Alcohol')
plt.legend()
plt.show()

# %%
# boxplot
df = pd.read_csv("http://51.91.120.89/extras/pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
plt.figure(figsize=(12,14))
sns.boxplot(data=df, x="Attack", y="Type 1", color="red", whis=1)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Type 1'>

# %%
plt.figure(figsize=(16,11))
sns.boxplot(data=df, y="Attack", x="Type 1", color="red", whis=1, hue="Legendary")
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Attack'>

# %%
# heatmap chart
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df1 = pd.pivot_table(df, index="month", columns="year", values="passengers")
df1
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df1, annot=True, fmt="d", cmap="jet")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>
